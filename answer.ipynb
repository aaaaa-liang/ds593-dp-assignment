# %% [markdown]
# ## Part 1: Plain Aggregates and Privacy

# %% [markdown]
# ### Question 1:
# Look at the result of this count query. Note that it does not include any name, email, or other personally identifiable information. What can you nevertheless learn about Kinan's musical tastes? What possible genres might they have chosen? Alternatively, what genres is it impossible for them to have chosen?

# %% [markdown]
# ### Answer:
# By looking at the result of the count query, I couldn't tell much about Kinan's musical taste. However, I would assume that Kinan's age falls between the late 20s and early 30s, such as from 26 to 32, given that most people would likely complete their PhDs around this range. As a result, the possible genres Kinan may like are pop, house, or metal music, while country, rock, and hip hop are out of the equation.​

# %% [markdown]
# ### Question 2:
# What did you find out about Kinan? Are your findings consistent with Question 1? Combine the two together to learn Kinan's exact age.
#
# ### Answer:
# Using the strategy of linking attack, I googled Kinan Bab and found his website. At the bottom of the webpage, he mentions that he goes to Metal shows for fun and recommends Vildhjarta, which is a Swedish progressive metal band. The findings are consistent with my answer above, and therefore, I believe Kinan likes Metal music. Once I combine this information with my guess on the age range, I would say Kinan is **31 years old**.

# %% [markdown]
# ### Question 3:
# Identify Kinan's favorite color. What is it? How easy or obvious is this to do, and why?
#
# ### Answer:
# Kinan's favorite color is **Black**. It is easy to identify because I know he is 31 years old and I confirmed that only one person is 31 years old in this dataset by running 'python3 client.py count age'.

# %% [markdown]
# ### Question 4:
# What information can you learn about Kinan's favorite sport from the above query?
#
# ### Answer:
# Kinan's favorite sport could be **either baseball or e-sports** because there are two sets of the 30-35 age group in the result.

# %% [markdown]
# ### Question 5:
# What is Kinan's favorite sport?
#
# ### Answer:
# Kinan's favorite sport is likely **baseball**. Since Kinan is 31 years old now, he would have been 30 or 31 years old last year. According to the table, the sports that are associated with the ages of 30 and 31 include American football, soccer, and baseball. Only baseball overlaps with my assumption above. At the bottom of his webpage, he also mentions he likes Red Sox.

# %% [markdown]
# ## Part 2: Implementing Differential Privacy

# %% [markdown]
# ### Question 6:
# Run dp.py several times varying the epsilon privacy parameter for different values between 10 and 0.01. What happens when the privacy parameter grows larger or smaller? How does that affect privacy?

# %%
# import packages
from dp import dp_histogram
from IPython.display import Image

# %% [markdown]
# #### Epsilon = 0.01

# %%
# !python3 dp.py 0.01
Image('dp-plot.png')
# Out:
# Using epsilon = 0.01
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 7                             |
# | 19                            | Pop                           | 7                             |
# | 20                            | Pop                           | -61                           |
# | 20                            | Pop                           | -61                           |
# | 21                            | Country                       | 252                           |
# | 21                            | Country                       | 252                           |
# | 21                            | Pop                           | 31                            |
# | 21                            | Pop                           | 31                            |
# ...

# %% [markdown]
# #### Epsilon = 0.05

# %%
# !python3 dp.py 0.05
Image('dp-plot.png')
# Out:
# Using epsilon = 0.05
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 26                            |
# | 19                            | Pop                           | 26                            |
# | 20                            | Pop                           | -4                            |
# | 20                            | Pop                           | -4                            |
# | 21                            | Country                       | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Pop                           | 73                            |
# | 21                            | Pop                           | 73                            |
# ...

# %% [markdown]
# #### Epsilon = 0.1

# %%
# !python3 dp.py 0.1
Image('dp-plot.png')
# Out:
# Using epsilon = 0.1
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | -14                           |
# | 19                            | Pop                           | -14                           |
# | 20                            | Pop                           | 16                            |
# | 20                            | Pop                           | 16                            |
# | 21                            | Country                       | -12                           |
# | 21                            | Country                       | -12                           |
# | 21                            | Pop                           | -26                           |
# | 21                            | Pop                           | -26                           |
# ...

# %% [markdown]
# #### Epsilon = 1.0

# %%
# !python3 dp.py 1.0
Image('dp-plot.png')
# Out:
# Using epsilon = 1.0
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | -1                            |
# | 19                            | Pop                           | -1                            |
# | 20                            | Pop                           | 2                             |
# | 20                            | Pop                           | 2                             |
# | 21                            | Country                       | 0                             |
# | 21                            | Country                       | 0                             |
# | 21                            | Pop                           | 1                             |
# | 21                            | Pop                           | 1                             |
# ...

# %% [markdown]
# #### Epsilon = 5

# %%
# !python3 dp.py 5
Image('dp-plot.png')
# Out:
# Using epsilon = 5.0
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 1                             |
# | 19                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Pop                           | 1                             |
# | 21                            | Pop                           | 1                             |
# ...

# %% [markdown]
# #### Epsilon = 8

# %%
# !python3 dp.py 8
Image('dp-plot.png')
# Out:
# Using epsilon = 8.0
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 1                             |
# | 19                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Pop                           | 1                             |
# | 21                            | Pop                           | 1                             |
# ...

# %% [markdown]
# #### Epsilon = 10

# %%
# !python3 dp.py 10
Image('dp-plot.png')
# Out:
# Using epsilon = 10.0
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 1                             |
# | 19                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Pop                           | 1                             |
# | 21                            | Pop                           | 1                             |
# ...

# %% [markdown]
# ### Answer:
# I decided to set epsilon = 0.01, 0.05, 0.1, 1, 5, 8, and 10 for observation.
# - When the privacy parameter becomes smaller (such as 0.01, 0.05, and 0.1), I notice more noises are added to the dataset, which makes it hard to distinguish between real and fake responses.
# - When the privacy parameter grows larger (such as 1, 5, 8, and 10), I observe less noises are applied and it becomes easier and easier to identify the real values.
#
# Therefore, the smaller the privacy parameter is, the more privacy it will provide.

# %% [markdown]
# ### Question 7:
# Look at the plot generated with privacy parameter epsilon = 0.5. What is the most likely value? What is the expected (i.e., average) value? How do they relate to the actual value (i.e., the query excuted without any noise via client.py)? How does the plot change for different values of the privacy parameter?
# Please include the generated plot for epsilon = 0.5 in your submission.

# %%
# !python3 client.py count age music
# Out:
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Pop                           | 1                             |
# | 21                            | Rock                          | 1                             |
# | 22                            | Country                       | 1                             |
# | 22                            | Pop                           | 4                             |
# | 22                            | Rock                          | 1                             |
# | 23                            | Hip Hop                       | 2                             |
# ...

# %% [markdown]
# Before adding noise, the first row is age = 19, music = pop, and count = 1.

# %%
# !python3 dp.py 0.5
Image('dp-plot.png')
# Out:
# Using epsilon = 0.5
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 2                             |
# | 19                            | Pop                           | 2                             |
# | 20                            | Pop                           | 0                             |
# | 20                            | Pop                           | 0                             |
# | 21                            | Country                       | 2                             |
# | 21                            | Country                       | 2                             |
# | 21                            | Pop                           | -1                            |
# | 21                            | Pop                           | -1                            |
# ...

# %% [markdown]
# After adding noise using Epsilon = 0.5, the first row became age = 19, music = pop, and count = 2.

# %% [markdown]
# ### Answer:
# The plot above shows that the most likely value for the first row (age = 19, music = Pop) is around 1 to 2. The expected count among multiple runs is also close to this range, around 0 to 3. Both the most likely and average noise values are very close to the true value (count = 1) from the client.py query. This reveals that even though Laplace noise introduces variation, the overall result remains centered near the original count.
# - When using different values for the privacy parameter above, a smaller epsilon adds more noise, the plot is wider, and the count value is more spread out.
# - On the contrary, a larger epsilon reduces noise, the plot is narrower, and the count value is closer to the actual value.

# %% [markdown]
# ## Part 3: Differential Privacy and Composition

# %% [markdown]
# ### Question 8:
# Run the composition attack against the average age grouped by programming experience. What can you deduce from the exposed averages about Kinan's programming experience level? How confident are you in what you have deduced? Are there scenarios where they might be wrong?

# %%
# !python3 client.py dp avg age programming
# Out:
# | programming                   | AVG(age)                      |
# ...
# | 0-3 Years                     | 44.349                        |
# | 3-5 Years                     | 12.58                         |
# | 5-8 Years                     | 25.816                        |
# | More than 10 Years            | -3.023                        |
# ...

# %%
# !python3 client.py dp avg age programming
# Out:
# | programming                   | AVG(age)                      |
# ...
# | 0-3 Years                     | 21.66                         |
# | 3-5 Years                     | 23.202                        |
# | 5-8 Years                     | 15.598                        |
# | More than 10 Years            | -66.427                       |
# ...

# %% [markdown]
# I ran the code several times, and each time the values flunctuate.

# %%
# !python3 composition.py
# Out:
# TESTING: the two histograms should be (almost) equal.
#
# Non-noised histogram (from part 1):
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 1                             |
# | 20                            | Pop                           | 1                             |
# | 21                            | Country                       | 1                             |
# | 21                            | Pop                           | 1                             |
# | 21                            | Rock                          | 1                             |
# | 22                            | Country                       | 1                             |
# | 22                            | Pop                           | 4                             |
# | 22                            | Rock                          | 1                             |
# ...

# %% [markdown]
# ### Answer:
# After running the 200 iterations, the counts of the non-noised and noised histograms become similar. To find out Kinan's programming experience level, I look at the exposed averages and exposed counts:
#
# Based on my understanding, I know that Kinan is likely 31 years old and has several years of programming experience based on his educational background. I took a closer look at his website, he received a bachelors, masters, and PhD in CS and started his bachelors around 2012. This means that he has likely been coding for around 13 years.
# - From the exposed average histogram, the average age is around 32 years old for the category of 5-8 years of programming experience level, while it is around 18 years old for the more than 10 years group. The former group fits Kinan's estimated age, but the latter makes more sense for estimated programming experience.
#
# Therefore, I'm somewhat confident that Kinan has either 5-8 years or more than 10 years of programming experience, but I need to confirm which category he falls under. This is because I'm influenced by the average age group result, which could be impacted by one person or a group of people's age as well.

# %% [markdown]
# ### Question 9:
# Reuse your composition attack from question 8 to compute the exact non-noised counts per programming experience level. Deduce Kinan's programming experience level, with high confidence, by looking at both the exposed counts and the previously exposed averages. Now summarize everything you've learned about Kinan!

# %%
# !python3 client.py dp count0 programming
# Out:
# | programming                   | COUNT                         |
# ...
# | 0-3 Years                     | 7                             |
# | 3-5 Years                     | 15                            |
# | 5-8 Years                     | 3                             |
# | More than 10 Years            | 3                             |
# ...

# %% [markdown]
# I ran this code several times. The count range for more than 10 years is often between 2 and 4. The count range for 5-8 years shift slightly more and is often between 0 and 10.

# %% [markdown]
# ### Answer:
# Using the same code to expose count:
# - From the exposing count histogram, the count shows that around ​4 people indicated that they have 5-8 years or more than 10 years of experience. This validates my assumption that only a few people should have extensive years of experience and Kinan is likely one out of the four.
#
# I compared the exposed averages and exposed counts across experience groups. With high confidence, I believe that 5-8 years of programming experience fits best in this context because this group has the highest average age (around 28 to 30 years old). Even though the more than 10 years group may be a better fit based on his academic background, the exposed average indicates that this group’s average age is much lower.
#
# Overall, here's what I know about Kinan:
# - He is 31 years old.
# - He likes metal music.
# - His favorite color is black.
# - He has 5-8 years of programming experience.

# %% [markdown]
# ### Question 10:
# Does the class you implemented suffice to truly enforce that a dataset is never used beyond a certain privacy budget? Can developers intentionally or unintentionally over-use the dataset beyond the privacy budget? At a very high level, how would you design a different privacy budget enforcment mechanism that does not suffer these drawbacks?

# %%
# !python budget.py
# Out:
# Query approved. Remaining budget: 1.50
#
# | programming                   | AVG(age)                      |
# ...
# | 0-3 Years                     | 48.622                        |
# | 3-5 Years                     | 31.229                        |
# | 5-8 Years                     | 45.617                        |
# | More than 10 Years            | -61.898                       |
# ...
#
# Query approved. Remaining budget: 1.00
#
# | age                           | music                         | COUNT                         |
# ...
# | 19                            | Pop                           | 1                             |
# | 20                            | Pop                           | -1                            |
# | 21                            | Country                       | 2                             |
# | 21                            | Pop                           | 1                             |
# ...

# %% [markdown]
# ### Answer:
# The current BudgetTracker class tracks and enforces a privacy budget within a single instance of the tracker. Once the budget runs out, it raises an error and stops further queries. However, it doesn't truly enforce a privacy budget because any developer can bypass the budget by creating a new BudgetTracker with a new budget. This essentially resets the privacy budget each time a user generates a new instance to use. Additionally, the protection only works on the code itself, meaning malicious developers can simply disable it.
#
# At a high level, I would create a privacy budget enforcement design that is stored on the server. The server will control the privacy budget of the users and datasets. It will also validate the amount of epsilon requested and reject or reschedule any queries that went over budget. This way, it can prevent intentional or unintentional misuse of the privacy budget.
